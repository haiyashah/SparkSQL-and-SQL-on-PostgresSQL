# %% [markdown]
# # Homework 2, Q6: Screenshot of Successful Running of a cluster on GCP

# %% [markdown]
# Haiya Niraj Shah \
# Andrew id - haiyas

# %%
print("Screenshot of Successful Running of a cluster on GCP")

from IPython.display import Image
Image(filename='q6.png')
# Out:
# Screenshot of Successful Running of a cluster on GCP

# %% [markdown]
# ### References
#
# - Google Cloud. (n.d.). gcloud CLI overview. Retrieved from
# https://cloud.google.com/sdk/docs/overview
