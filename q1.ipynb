# %% [markdown]
# # Homework 1: Question 1 - Creating a table

# %% [markdown]
# Haiya Niraj Shah \
# Andrew id - haiyas

# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder \
    .appName("GoogleNewsFeed") \
    .getOrCreate()

# %%
spark.sql("CREATE DATABASE IF NOT EXISTS News")
spark.sql("USE News")

spark.sql("""
CREATE TABLE IF NOT EXISTS google_newsFeed (
    id STRING,
    lastBuildDate STRING,
    title STRING,
    link STRING,
    pubDate STRING,
    description STRING,
    source STRING
)
USING PARQUET
""")
# Out:
# DataFrame[]

# %%
spark.sql("DESCRIBE News.google_newsFeed").show(truncate=False)
# Out:
# +-------------+---------+-------+
# |col_name     |data_type|comment|
# +-------------+---------+-------+
# |id           |string   |NULL   |
# |lastBuildDate|string   |NULL   |
# |title        |string   |NULL   |
# |link         |string   |NULL   |
# |pubDate      |string   |NULL   |
# |description  |string   |NULL   |
# |source       |string   |NULL   |
# +-------------+---------+-------+

# %% [markdown]
# Table is successfully created, defined within its own DB schema named “News”.

# %% [markdown]
# ### References
#
# ### Class Materials
# - Lecture_2_Introduction_to_Cloud_And_Spark on creating tables
